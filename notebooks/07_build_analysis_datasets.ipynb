# %% [markdown]
# # Phase 7: Build analysis-ready datasets
#
# This notebook is a thin, reproducible wrapper around `src.build_analysis_datasets`. It prepares joined datasets and coverage audits only.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.build_analysis_datasets import main as build_analysis_datasets

build_analysis_datasets()

# %%
import csv

outputs = [
    PROJECT_ROOT / 'data/processed/analysis_municipality_reading_spending_2024.csv',
    PROJECT_ROOT / 'data/processed/analysis_althingi_school_outcomes_mapped.csv',
    PROJECT_ROOT / 'data/processed/analysis_municipality_althingi_summary.csv',
    PROJECT_ROOT / 'outputs/tables/analysis_dataset_coverage_audit.csv',
]
for path in outputs:
    with path.open(encoding='utf-8', newline='') as file:
        rows = list(csv.DictReader(file))
    print(f'{path.relative_to(PROJECT_ROOT)}: {len(rows):,} rows')
