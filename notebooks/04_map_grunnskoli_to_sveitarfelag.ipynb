# %% [markdown]
# # Map Grunnskoli to Sveitarfelag
#
# Phase 4 mapping-only notebook. This wraps `src.map_grunnskoli_to_sveitarfelag` and `src.validate_grunnskoli_sveitarfelag_crosswalk`. It creates a reusable crosswalk plus manual-review files; it does not perform analysis, ranking, dashboarding, spending work, or school-to-sveitarfelag analysis beyond the crosswalk itself.

# %%
from pathlib import Path
import csv
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.map_grunnskoli_to_sveitarfelag import main as map_main

map_main()

# %%
from src.validate_grunnskoli_sveitarfelag_crosswalk import main as validate_main

validate_main()

# %%
paths = {
    'crosswalk': PROJECT_ROOT / 'data/processed/grunnskoli_sveitarfelag_crosswalk.csv',
    'manual': PROJECT_ROOT / 'data/manual/manual_school_crosswalk.csv',
    'review': PROJECT_ROOT / 'outputs/tables/school_mapping_review.csv',
    'audit': PROJECT_ROOT / 'outputs/tables/school_mapping_audit.csv',
}

for name, path in paths.items():
    with path.open(encoding='utf-8', newline='') as file:
        rows = list(csv.DictReader(file))
    print(name, len(rows))
    print(rows[:3])
