# %% [markdown]
# # Phase 5: Extract municipality-level grunnskóli spending\n\nThis notebook is an inspectable wrapper around `src.extract_education_spending_sveitarfelag`. It does not join outcomes, create rankings, or run analysis.

# %%
from pathlib import Path
import csv
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.extract_education_spending_sveitarfelag import main\n\nmain()

# %%
output_path = PROJECT_ROOT / 'data' / 'processed' / 'education_spend_sveitarfelag.csv'\nwith output_path.open(encoding='utf-8', newline='') as f:\n    rows = list(csv.DictReader(f))\n\nlen(rows), sorted({row['year'] for row in rows}), len({row['sveitarfelag_source'] for row in rows}), sorted({row['spending_metric'] for row in rows})

# %%
rows[:5]

# %%
audit_path = PROJECT_ROOT / 'outputs' / 'tables' / 'education_spending_extraction_audit.csv'\nwith audit_path.open(encoding='utf-8', newline='') as f:\n    audit_rows = list(csv.DictReader(f))\n\n[row for row in audit_rows if row['audit_section'] == 'summary']
