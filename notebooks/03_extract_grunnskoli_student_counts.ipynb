# %% [markdown]
# # Extract Grunnskoli Student Counts
#
# Phase 3 extraction-only notebook. This wraps `src.extract_grunnskoli_student_counts` and `src.validate_grunnskoli_student_counts` for Hagstofa table SKO02102. It creates denominator/proxy count datasets only; it does not perform school matching, ranking, dashboarding, spending analysis, or rate analysis.

# %%
from pathlib import Path
import csv
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.extract_grunnskoli_student_counts import main as extract_main

extract_main()

# %%
from src.validate_grunnskoli_student_counts import main as validate_main

validate_main()

# %%
paths = {
    'student_counts': PROJECT_ROOT / 'data/processed/grunnskoli_student_counts.csv',
    'tenth_grade_counts': PROJECT_ROOT / 'data/processed/grunnskoli_10th_grade_counts.csv',
    'audit': PROJECT_ROOT / 'outputs/tables/grunnskoli_student_counts_audit.csv',
}

for name, path in paths.items():
    with path.open(encoding='utf-8', newline='') as file:
        rows = list(csv.DictReader(file))
    print(name, len(rows))
    print(rows[:3])
