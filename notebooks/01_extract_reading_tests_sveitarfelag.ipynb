# %% [markdown]
# # Extract Reading Tests by Sveitarfelag
#
# Small, inspectable wrapper around `src.extract_reading_tests_sveitarfelag`. The extractor caches public source HTML/text, writes the processed long CSV, and writes an audit table.

# %%
from pathlib import Path
import csv
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.extract_reading_tests_sveitarfelag import main, PROCESSED_PATH, AUDIT_PATH

main()
PROCESSED_PATH, AUDIT_PATH

# %%
with PROCESSED_PATH.open(encoding='utf-8', newline='') as file:
    rows = list(csv.DictReader(file))

len(rows), rows[:5]

# %%
with AUDIT_PATH.open(encoding='utf-8', newline='') as file:
    audit = list(csv.DictReader(file))

audit
