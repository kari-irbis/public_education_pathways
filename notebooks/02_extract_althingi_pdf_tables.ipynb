# %% [markdown]
# # Extract Althingi PDF Tables
#
# Phase 2 extraction-only notebook. This wraps `src.extract_althingi_pdf_tables` and `src.validate_althingi_pdf_tables`, caches the public PDF, writes candidate CSVs, and surfaces audit/manual-review outputs.

# %%
from pathlib import Path
import csv
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.extract_althingi_pdf_tables import main as extract_main

extract_main()

# %%
from src.validate_althingi_pdf_tables import main as validate_main

validate_main()

# %%
paths = {
    'graduates': PROJECT_ROOT / 'data/processed/althingi_graduates_by_grunnskoli.csv',
    'framhald_grades': PROJECT_ROOT / 'data/processed/althingi_grades_by_framhaldsskoli_grunnskoli.csv',
    'grunnskoli_grades': PROJECT_ROOT / 'data/processed/althingi_grades_by_grunnskoli.csv',
    'audit': PROJECT_ROOT / 'outputs/tables/althingi_pdf_extraction_audit.csv',
    'manual_review': PROJECT_ROOT / 'data/interim/althingi_pdf_manual_review_rows.csv',
}

for name, path in paths.items():
    with path.open(encoding='utf-8', newline='') as file:
        rows = list(csv.DictReader(file))
    print(name, len(rows))
    print(rows[:3])
